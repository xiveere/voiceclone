# %%
# Flush CUDA cache
import torch
torch.cuda.empty_cache()

# %%
# Change continue_path in vits_tts.py to match --continue_path arg if needed
# !CUDA_VISIBLE_DEVICES="0,1,2,3"  python -m trainer.distribute --script vits_tts.py --continue_path "vitstts_checkpoint/vits_tyler1_phonemes-February-19-2024_01+52AM-2b31060/"

# %%
# !CUDA_VISIBLE_DEVICES="0,1,2,3"  python -m trainer.distribute --script vits_tts.py --restore_path "vitstts_checkpoint/tts_models--en--ljspeech--vits/model_file.pth"
# Out:
# ['vits_tts.py', '--continue_path=', '--restore_path=vitstts_checkpoint/tts_models--en--ljspeech--vits/model_file.pth', '--group_id=group_2024_02_29-085951', '--use_ddp=true', '--rank=0']
# ['vits_tts.py', '--continue_path=', '--restore_path=vitstts_checkpoint/tts_models--en--ljspeech--vits/model_file.pth', '--group_id=group_2024_02_29-085951', '--use_ddp=true', '--rank=1']
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
# ...
