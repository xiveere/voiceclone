# %%
from IPython.display import Audio
import os

config_path = "vitstts_checkpoint/vits_ljspeech-January-14-2024_06+00PM-dac07d8/config.json"
model_path = "vitstts_checkpoint/vits_ljspeech-January-14-2024_06+00PM-dac07d8/best_model.pth"
text = "Mic test one two three. This is my first generated voice"

def generate_t1(text = None, config_path = config_path, model_path = model_path, file_name = "test.wav"):

    if text == None:
        return
    else:
        os.system('tts --text "{0}" \
            --config_path "{1}" \
            --model_path "{2}" \
            --out_path "generated_audio/{3}" \
            --use_cuda true'.format(text, config_path, model_path, file_name))
            

        Audio("generated_audio/{}".format(file_name))
    return

generate_t1(text, config_path, model_path)
# Out:
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/TTS/bin/synthesize.py", line 338, in main
#     from TTS.api import TTS
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/TTS/api.py", line 7, in <module>
#     from torch import nn
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/torch/__init__.py", line 1750, in <module>
#     from . import _meta_registrations
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/torch/_meta_registrations.py", line 8, in <module>
#     from torch._decomp import (
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/torch/_decomp/__init__.py", line 190, in <module>
#     import torch._decomp.decompositions
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/torch/_decomp/decompositions.py", line 10, in <module>
#     import torch._prims as prims
# ...

# %%
Audio("generated_audio/{}".format("test.wav"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("generated_audio/{}".format("test.wav"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import torch
from TTS.api import TTS

config_path = "vitstts_checkpoint/vits_ljspeech-January-14-2024_06+00PM-dac07d8/config.json"
model_path = "vitstts_checkpoint/vits_ljspeech-January-14-2024_06+00PM-dac07d8/best_model.pth"
text = "Mic test one two three. Welcome chat, it's Tyler 1! This is my first generated voice"

tts = TTS(model_path=model_path, config_path = config_path, progress_bar=True, gpu = True)

tts.tts_to_file(text=text, file_path="generated_audio/test.wav", language = "en")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /home/ubuntu/.local/lib/python3.10/site-packages/TTS/api.py:70: UserWarning: `gpu` will be deprecated. Please use `tts.to(device)` instead.
#   warnings.warn("`gpu` will be deprecated. Please use `tts.to(device)` instead.")
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
# ...

# %%
TTS?
