# %%
# Flush CUDA cache
import torch
torch.cuda.empty_cache()

# %%
# Change continue_path in vits_tts.py to match --continue_path arg if needed
# !CUDA_VISIBLE_DEVICES="0,1,2,3" python -m trainer.distribute --script xttsv2.py

# %%
# !CUDA_VISIBLE_DEVICES="0,1,2,3"  python -m trainer.distribute --script xttsv2.py
# Out:
# ['xttsv2.py', '--continue_path=', '--restore_path=', '--group_id=group_2024_03_05-074831', '--use_ddp=true', '--rank=0']
# ['xttsv2.py', '--continue_path=', '--restore_path=', '--group_id=group_2024_03_05-074831', '--use_ddp=true', '--rank=1']
# ['xttsv2.py', '--continue_path=', '--restore_path=', '--group_id=group_2024_03_05-074831', '--use_ddp=true', '--rank=2']
# ['xttsv2.py', '--continue_path=', '--restore_path=', '--group_id=group_2024_03_05-074831', '--use_ddp=true', '--rank=3']
# 2024-03-05 07:48:35.359720: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
