# %%
# This notebook runs on TTS

# !pip install TTS

# %%
# We can run commands on the terminal
# This cell generates an audio
# It downloads the default model if you don't have it. Take note of where it is downloaded and copy the folder to somewhere more easily found

# !tts --text "This is the default text to speech model!!!" --model_name "tts_models/en/ljspeech/vits" --out_path "./generated_audio/test.wav"
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
#  > tts_models/en/ljspeech/vits is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Text: This is the default text to speech model!!!
#  > Text splitted to sentences.
# ['This is the default text to speech model!!!']
#  > Processing time: 0.2549149990081787
#  > Real-time factor: 0.08815677114382592
#  > Saving output to ./generated_audio/test.wav

# %%
# This cell generates it programmatically
# I've moved the pretrained model to the pretrained folder

from TTS.utils.synthesizer import Synthesizer
from IPython.display import Audio

# model_path = "pretrained/tts_models--en--ljspeech--vits/model_file.pth" # Pretrained model path
# config_path = "pretrained/tts_models--en--ljspeech--vits/config.json" # Pretrained config path

# model_path = "vitstts_checkpoint/vits_tyler1_phonemes-January-26-2024_03+51PM-7e6c2b3/best_model.pth" # phonemes
# config_path = "vitstts_checkpoint/vits_tyler1_phonemes-January-26-2024_03+51PM-7e6c2b3/config.json" #phonemes

model_path =  "vitstts_checkpoint/vits_tyler1_noshouting_phonemes-January-30-2024_12+17PM-7e6c2b3/best_model_4981.pth" # phonemes no shouting
config_path = "vitstts_checkpoint/vits_tyler1_noshouting_phonemes-January-30-2024_12+17PM-7e6c2b3/config.json" # phonemes no shouting
out_path = out_path = "generated_audio/test1.wav"

text = "Text to synthesize"

synthesizer = Synthesizer(model_path, config_path, use_cuda = True)

wav = synthesizer.tts(text)
synthesizer.save_wav(wav, out_path)

Audio(out_path)
# Out:
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Text splitted to sentences.
# ['Text to synthesize']
#  > Processing time: 1.3238680362701416
#  > Real-time factor: 0.5906298599821265
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
