# %%
import librosa
import os

wav_dur = [librosa.get_duration(path= 'wavs/' + file)for file in sorted(os.listdir('wavs'))]

# %%
import matplotlib.pyplot as plt

plt.hist(wav_dur)

plt.xlabel('Duration')
plt.ylabel('Count')
plt.title('Wav Length Histogram')
# Out:
# Text(0.5, 1.0, 'Wav Length Histogram')
