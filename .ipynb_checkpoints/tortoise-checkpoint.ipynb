#  82%|████████▏ | 961M/1.17G [00:08<00:01, 121MiB/s]
#  83%|████████▎ | 973M/1.17G [00:08<00:01, 117MiB/s]
#  84%|████████▍ | 985M/1.17G [00:08<00:01, 119MiB/s]
#  85%|████████▌ | 997M/1.17G [00:08<00:01, 118MiB/s]
#  86%|████████▌ | 1.01G/1.17G [00:08<00:01, 116MiB/s]
#  87%|████████▋ | 1.02G/1.17G [00:08<00:01, 117MiB/s]
#  88%|████████▊ | 1.03G/1.17G [00:08<00:01, 116MiB/s]
#  89%|████████▉ | 1.04G/1.17G [00:08<00:01, 116MiB/s]
#  90%|█████████ | 1.06G/1.17G [00:08<00:00, 119MiB/s]
#  91%|█████████▏| 1.07G/1.17G [00:09<00:01, 99.7MiB/s]
#  92%|█████████▏| 1.08G/1.17G [00:09<00:00, 103MiB/s]
#  93%|█████████▎| 1.09G/1.17G [00:09<00:00, 106MiB/s]
#  94%|█████████▍| 1.10G/1.17G [00:09<00:00, 108MiB/s]
#  95%|█████████▌| 1.11G/1.17G [00:09<00:00, 109MiB/s]
#  96%|█████████▌| 1.12G/1.17G [00:09<00:00, 110MiB/s]
#  97%|█████████▋| 1.14G/1.17G [00:09<00:00, 109MiB/s]
#  98%|█████████▊| 1.15G/1.17G [00:09<00:00, 110MiB/s]
# 100%|██████████| 1.17G/1.17G [00:10<00:00, 114MiB/s]
#  80%|████████  | 20.2M/25.2M [00:00<00:00, 104MiB/s]
# 100%|██████████| 25.2M/25.2M [00:00<00:00, 41.7MiB/s]
#
#   9%|▉         | 9.13M/101M [00:00<00:01, 91.3MiB/s]
#  21%|██        | 20.8M/101M [00:00<00:00, 106MiB/s]
#  32%|███▏      | 32.4M/101M [00:00<00:00, 111MiB/s]
#  44%|████▍     | 44.8M/101M [00:00<00:00, 116MiB/s]
#  57%|█████▋    | 57.4M/101M [00:00<00:00, 120MiB/s]
#  69%|██████▉   | 69.4M/101M [00:00<00:00, 118MiB/s]
#  81%|████████  | 81.2M/101M [00:00<00:00, 116MiB/s]
# 100%|██████████| 101M/101M [00:01<00:00, 80.0MiB/s]
#  97%|█████████▋| 381M/391M [00:03<00:00, 119MiB/s]
# 100%|██████████| 391M/391M [00:03<00:00, 106MiB/s]
# 100%|██████████| 1.07k/1.07k [00:00<00:00, 2.15kiB/s]
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
# 2024-02-15 09:44:56.966844: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-15 09:44:57.057794: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  > Using model: tortoise

# %%
tts.tts_to_file(text="Hello, my name is Manmay , how are you?",
                file_path="generated_audio/tortoise_output.wav",
                voice_dir="data/wavs/",
                speaker="Tyler1",
                num_autoregressive_samples=1,
                diffusion_iterations=10)
# Out:
#  > Text splitted to sentences.
# ['Hello, my name is Manmay , how are you?']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tts.tts_to_file(text="Hello, my name is Manmay , how are you?",
#       2                 file_path="generated_audio/tortoise_output.wav",
#       3                 voice_dir="data/wavs/",
#       4                 speaker="Tyler1",
#       5                 num_autoregressive_samples=1,
#       6                 diffusion_iterations=10)
#
# File ~/tts/TTS/TTS/api.py:334, in TTS.tts_to_file(self, text, speaker, language, speaker_wav, emotion, speed, pipe_out, file_path, split_sentences, **kwargs)
#     303 """Convert text to speech.
#     304
#     305 Args:
#    (...)
#     330         Additional arguments for the model.
#     331 """
#     332 self._check_arguments(speaker=speaker, language=language, speaker_wav=speaker_wav, **kwargs)
# --> 334 wav = self.tts(
#     335     text=text,
#     336     speaker=speaker,
#     337     language=language,
#     338     speaker_wav=speaker_wav,
#     339     split_sentences=split_sentences,
#     340     **kwargs,
#     341 )
#     342 self.synthesizer.save_wav(wav=wav, path=file_path, pipe_out=pipe_out)
#     343 return file_path
#
# File ~/tts/TTS/TTS/api.py:276, in TTS.tts(self, text, speaker, language, speaker_wav, emotion, speed, split_sentences, **kwargs)
#     248 """Convert text to speech.
#     249
#     250 Args:
#    (...)
#     271         Additional arguments for the model.
#     272 """
#     273 self._check_arguments(
#     274     speaker=speaker, language=language, speaker_wav=speaker_wav, emotion=emotion, speed=speed, **kwargs
#     275 )
# --> 276 wav = self.synthesizer.tts(
#     277     text=text,
#     278     speaker_name=speaker,
#     279     language_name=language,
#     280     speaker_wav=speaker_wav,
#     281     reference_wav=None,
#     282     style_wav=None,
#     283     style_text=None,
#     284     reference_speaker_name=None,
#     285     split_sentences=split_sentences,
#     286     **kwargs,
#     287 )
#     288 return wav
#
# File ~/tts/TTS/TTS/utils/synthesizer.py:386, in Synthesizer.tts(self, text, speaker_name, language_name, speaker_wav, style_wav, style_text, reference_wav, reference_speaker_name, split_sentences, **kwargs)
#     384 for sen in sens:
#     385     if hasattr(self.tts_model, "synthesize"):
# --> 386         outputs = self.tts_model.synthesize(
#     387             text=sen,
#     388             config=self.tts_config,
#     389             speaker_id=speaker_name,
#     390             voice_dirs=self.voice_dir,
#     391             d_vector=speaker_embedding,
#     392             speaker_wav=speaker_wav,
#     393             language=language_name,
#     394             **kwargs,
#     395         )
#     396     else:
#     397         # synthesize voice
#     398         outputs = synthesis(
#     399             model=self.tts_model,
#     400             text=sen,
#    (...)
#     408             language_id=language_id,
#     409         )
#
# File ~/tts/TTS/TTS/tts/models/tortoise.py:521, in Tortoise.synthesize(self, text, config, speaker_id, voice_dirs, **kwargs)
#     519 if voice_dirs is not None:
#     520     voice_dirs = [voice_dirs]
# --> 521     voice_samples, conditioning_latents = load_voice(speaker_id, voice_dirs)
#     523 else:
#     524     voice_samples, conditioning_latents = load_voice(speaker_id)
#
# File ~/tts/TTS/TTS/tts/layers/tortoise/audio_utils.py:122, in load_voice(voice, extra_voice_dirs)
#     119     return None, None
#     121 voices = get_voices(extra_voice_dirs)
# --> 122 paths = voices[voice]
#     123 if len(paths) == 1 and paths[0].endswith(".pth"):
#     124     return None, torch.load(paths[0])
#
# KeyError: 'Tyler1'
